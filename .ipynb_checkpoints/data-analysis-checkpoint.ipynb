# %% [markdown]
# # Data analysis to match like-minded friends
# We are using an open access dataset aquired from a questionnaire of 1010 young Slovakians. The dataset is called Young People Survey and is available through Kaggle [here](https://www.kaggle.com/miroslavsabo/young-people-survey).
#
# Possible projects:
# - Clustering - find natural groupings of people.
# - Recommender system - recommend people to eachother based on how many shared interests they have.
# - Predicting questionnaire responses based on other questions. Could be useful for if someone only partially fills in the questionnaire.
# - Visualisation - What data do we need to visualise and how can we do that best?

# %% [markdown]
# ## Data preparation
# Contents:
# - Adding names (done)
# - Selecting columns that are relevant for friend-finding. (to do)
# - Remove outliers - people who have probably incorrectly answered questions and people who have randomly answered questions. (to do)

# %% [markdown]
# ### Adding names
# The Young People Survey dataset is anonymous. For our app, we will have the participants enter their name into the questionnaire. To make this dataset mimic the dataset we will create in our app, we need to give the participants names.

# %%
import pandas as pd
import numpy as np

# %%
# Read the  data and store as a Pandas dateframe
df = pd.read_csv("responses.csv")

# %%
df.describe()
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1003.000000  1008.000000  1007.000000  1004.000000
# mean      2.123383         2.956132     2.761905     3.471698     3.761952
# std       1.076136         1.252570     1.260845     1.161400     1.184861
# min       1.000000         1.000000     1.000000     1.000000     1.000000
# 25%       1.000000         2.000000     2.000000     3.000000     3.000000
# 50%       2.000000         3.000000     3.000000     4.000000     4.000000
# 75%       3.000000         4.000000     4.000000     4.000000     5.000000
# max       5.000000         5.000000     5.000000     5.000000     5.000000
#
#        Metal or Hardrock         ...          Shopping centres  \
# count        1007.000000         ...               1008.000000
# mean            2.361470         ...                  3.234127
# std             1.372995         ...                  1.323062
# min             1.000000         ...                  1.000000
# 25%             1.000000         ...                  2.000000
# 50%             2.000000         ...                  3.000000
# 75%             3.000000         ...                  4.000000
# max             5.000000         ...                  5.000000
#
#        Branded clothing  Entertainment spending  Spending on looks  \
# count       1008.000000             1007.000000        1007.000000
# mean           3.050595                3.201589           3.106256
# std            1.306321                1.188947           1.205368
# min            1.000000                1.000000           1.000000
# 25%            2.000000                2.000000           2.000000
# 50%            3.000000                3.000000           3.000000
# 75%            4.000000                4.000000           4.000000
# max            5.000000                5.000000           5.000000
#
#        Spending on gadgets  Spending on healthy eating          Age  \
# count          1010.000000                  1008.00000  1003.000000
# mean              2.870297                     3.55754    20.433699
# std               1.284970                     1.09375     2.828840
# min               1.000000                     1.00000    15.000000
# 25%               2.000000                     3.00000    19.000000
# 50%               3.000000                     4.00000    20.000000
# 75%               4.000000                     4.00000    22.000000
# max               5.000000                     5.00000    30.000000
#
#            Height      Weight  Number of siblings
# count  990.000000  990.000000         1004.000000
# mean   173.514141   66.405051            1.297809
# std     10.024505   13.839561            1.013348
# min     62.000000   41.000000            0.000000
# 25%    167.000000   55.000000            1.000000
# 50%    173.000000   64.000000            1.000000
# 75%    180.000000   75.000000            2.000000
# max    203.000000  165.000000           10.000000
#
# [8 rows x 139 columns]

# %%
# column labels
df.columns
# Out:
# Index(['Music', 'Slow songs or fast songs', 'Dance', 'Folk', 'Country',
#        'Classical music', 'Musical', 'Pop', 'Rock', 'Metal or Hardrock',
#        ...
#        'Age', 'Height', 'Weight', 'Number of siblings', 'Gender',
#        'Left - right handed', 'Education', 'Only child', 'Village - town',
#        'House - block of flats'],
#       dtype='object', length=150)

# %%
# Shape of data
df.shape
# Out:
# (1010, 150)

# %% [markdown]
# We need to know which participants are male and which are female, so that we can add names of the correct gender.

# %%
# number of males, females, and unknown gender
n_male = (df['Gender'] == 'male').sum()
n_female = (df['Gender'] == 'female').sum()
n_unknown = df['Gender'].isnull().sum()
print(n_male, n_female, n_unknown)
# Out:
# 411 593 6

# %% [markdown]
# There are 6 participants who did not give their gender, we'll give these people male names as there are fewer males in the dataset.
#
# We've created a list of male names and a list of female names which we can import and clean up as follows.

# %%
# Import name lists
df_female_names = pd.read_csv('female_names.csv')[:n_female]
df_male_names = pd.read_csv('male_names.csv')[:n_male + n_unknown]

# remove non-ascii characters which have occurred because the names were copied from a website.
df_male_names['Name'] = df_male_names['Name'].apply(lambda x: x.replace('\xa0', ' '))
df_female_names['Name'] = df_female_names['Name'].apply(lambda x: x.replace('\xa0', ' '))

# %%
# Add new column to main dataframe for name
df['Name'] = ''

# %%
# Set the indices of the male name dataframe to be the indices of the males (and unknowns) in the
# main dataframe.
df_male_names = df_male_names.set_index(df.index[(df['Gender'] == 'male') | df['Gender'].isnull()])

# Do the same for females.
df_female_names = df_female_names.set_index(df.index[(df['Gender'] == 'female')])

# %%
# Add names into main dataframe.
df['Name'] = df_male_names
df.loc[df['Gender'] == 'female', 'Name'] = df_female_names

# %% [markdown]
# Now we have a column of names with the appropriate genders.

# %%
# Print the gender and names of the last few rows.
df[['Gender', 'Name']].tail()
# Out:
#       Gender               Name
# 1005  female     Caroline Wilks
# 1006    male         Roy Martin
# 1007  female     Lelia Williams
# 1008  female  Lauren Williamson
# 1009    male         Ciaran May

# %% [markdown]
# ## Remove outliers

# %% [markdown]
# Explore data for abnormal values. Only the Age, Height, Weight, and Number of siblings questions allowed the participant to enter any value. So let's check the extreme values of these columns to see if there are any anomolies.

# %%
df[['Age', 'Height', 'Weight', 'Number of siblings']].agg(['min', 'max'])
# Out:
#       Age  Height  Weight  Number of siblings
# min  15.0    62.0    41.0                 0.0
# max  30.0   203.0   165.0                10.0

# %% [markdown]
# Age and number of siblings look ok. The height is measured in cm and the weight in kg, so the min height and max weight look like errors. Let's look more closely at these values.

# %%
df[df['Height'] < 120]
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 676    5.0                       4.0    2.0   2.0      1.0              2.0
#
#      Musical  Pop  Rock  Metal or Hardrock     ...       Height  Weight  \
# 676      2.0  1.0   2.0                2.0     ...         62.0    55.0
#
#      Number of siblings  Gender  Left - right handed                Education  \
# 676                 2.0  female         right handed  college/bachelor degree
#
#      Only child  Village - town  House - block of flats         Name
# 676          no            city          house/bungalow  Sarah Baker
#
# [1 rows x 151 columns]

# %% [markdown]
# That 62cm height looks like an error, given that she weighs 55kg. Let's replace it with NaN.

# %%
df.loc[676,'Height'] = np.NaN

# %%
df[df['Weight'] > 130]
# Out:
#      Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 885    3.0                       4.0    3.0   2.0      2.0              2.0
# 992    4.0                       4.0    4.0   1.0      4.0              4.0
#
#      Musical  Pop  Rock  Metal or Hardrock      ...       Height  Weight  \
# 885      3.0  4.0   4.0                4.0      ...          NaN   165.0
# 992      1.0  3.0   4.0                4.0      ...        200.0   150.0
#
#      Number of siblings  Gender  Left - right handed         Education  \
# 885                 0.0  female         right handed  secondary school
# 992                 1.0    male         right handed    masters degree
#
#      Only child  Village - town  House - block of flats          Name
# 885         yes            city          house/bungalow    Keava Mone
# 992          no            city          block of flats  Stacey Lewis
#
# [2 rows x 151 columns]

# %% [markdown]
# There are very few people with a weight of 150kg or more. The participants may have misread the units, thinking they were entering 150lb instead. Let's replace these extreme values with NaN

# %%
df.loc[885,'Weight'] = np.NaN
df.loc[992,'Weight'] = np.NaN

# %% [markdown]
# Next, let's check whether there are any people who have incorrectly answered whether they are an only child and how many siblings they have. If someone is an only child, they have no siblings.

# %%
df[['Only child', 'Number of siblings']][(df['Only child'] == 'yes') & (df['Number of siblings'] >= 1)]
# Out:
#     Only child  Number of siblings
# 3          yes                 1.0
# 25         yes                 1.0
# 28         yes                 2.0
# 47         yes                 1.0
# 48         yes                 1.0
# 65         yes                 1.0
# 70         yes                 1.0
# 71         yes                 1.0
# 73         yes                 1.0
# 131        yes                 2.0
# 134        yes                 1.0
# 141        yes                 1.0
# 156        yes                 1.0
# 161        yes                 2.0
# 165        yes                 1.0
# 169        yes                 2.0
# 175        yes                 2.0
# 176        yes                 2.0
# 195        yes                 1.0
# 205        yes                 1.0
# 239        yes                 1.0
# 241        yes                 1.0
# 247        yes                 2.0
# 253        yes                 2.0
# 258        yes                 1.0
# 287        yes                 1.0
# 293        yes                 1.0
# 304        yes                 2.0
# 308        yes                 2.0
# 316        yes                 1.0
# ..         ...                 ...
# 692        yes                 1.0
# 693        yes                 1.0
# 696        yes                 1.0
# 706        yes                 2.0
# 727        yes                 1.0
# 754        yes                 1.0
# 760        yes                 1.0
# 762        yes                 1.0
# 799        yes                 2.0
# 814        yes                 1.0
# 832        yes                 1.0
# 833        yes                 1.0
# 842        yes                 2.0
# 845        yes                 1.0
# 876        yes                 1.0
# 878        yes                 3.0
# 887        yes                 1.0
# 892        yes                 1.0
# 895        yes                 1.0
# 912        yes                 1.0
# 913        yes                 1.0
# 929        yes                 1.0
# 937        yes                 4.0
# 947        yes                 1.0
# 952        yes                 1.0
# 956        yes                 2.0
# 964        yes                 3.0
# 975        yes                 1.0
# 976        yes                 1.0
# 984        yes                 1.0
#
# [95 rows x 2 columns]

# %% [markdown]
# So there are 95 people who either incorrectly answered whether they are an only child or the number of siblings they have. Let's change these values to NaN for these participants.

# %%
i_error = df[['Only child', 'Number of siblings']][(df['Only child'] == 'yes') & (df['Number of siblings'] >= 1)].index
df.loc[i_error, ['Only child', 'Number of siblings']] = np.NaN

# %% [markdown]
# Now let's identify people who are likely to have randomly answered the questions. For this, we can use the [local outlier factor algorithm](https://en.wikipedia.org/wiki/Local_outlier_factor). TO DO

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import LocalOutlierFactor

# %%
df_float_only = df.dropna().loc[:, df.dtypes == float]
df_float_only_normalized = (df_float_only - df_float_only.min())/(df_float_only.max() - df_float_only.min())


# fit the model for outlier detection
clf = LocalOutlierFactor(n_neighbors=20)

clf.fit_predict(df_float_only_normalized)
X_scores = clf.negative_outlier_factor_

# # np.where(X_scores < -1.2)

df_dropna = df.dropna()
df_dropna['LOF score'] = X_scores
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_dropna.shape
# Out:
# (614, 152)

# %%
X_scores.shape
# Out:
# (614,)

# %%
print(df_dropna[df_dropna['LOF score'] < -1.4].iloc[0].to_string())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-ea735c00b5b3> in <module>()
# ----> 1 print(df_dropna[df_dropna['LOF score'] < -1.4].iloc[0].to_string())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1747
#    1748             # validate the location
# -> 1749             self._is_valid_integer(key, axis)
#    1750
#    1751             return self._get_loc(key, axis=axis)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _is_valid_integer(self, key, axis)
#    1636         l = len(ax)
#    1637         if key >= l or key < -l:
# -> 1638             raise IndexError("single positional indexer is out-of-bounds")
#    1639         return True
#    1640
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# # User recommendation
# In this section, we use collaborative filtering to recommend users to other users based on the similarity of their interests.

# %%
df.describe()
# Out:
#              Music  Slow songs or fast songs        Dance         Folk  \
# count  1007.000000               1008.000000  1006.000000  1005.000000
# mean      4.731877                  3.328373     3.113320     2.288557
# std       0.664049                  0.833931     1.170568     1.138916
# min       1.000000                  1.000000     1.000000     1.000000
# 25%       5.000000                  3.000000     2.000000     1.000000
# 50%       5.000000                  3.000000     3.000000     2.000000
# 75%       5.000000                  4.000000     4.000000     3.000000
# max       5.000000                  5.000000     5.000000     5.000000
#
#            Country  Classical music      Musical          Pop         Rock  \
# count  1005.000000      1003.000000  1008.000000  1007.000000  1004.000000
# mean      2.123383         2.956132     2.761905     3.471698     3.761952
# std       1.076136         1.252570     1.260845     1.161400     1.184861
# min       1.000000         1.000000     1.000000     1.000000     1.000000
# 25%       1.000000         2.000000     2.000000     3.000000     3.000000
# 50%       2.000000         3.000000     3.000000     4.000000     4.000000
# 75%       3.000000         4.000000     4.000000     4.000000     5.000000
# max       5.000000         5.000000     5.000000     5.000000     5.000000
#
#        Metal or Hardrock         ...          Shopping centres  \
# count        1007.000000         ...               1008.000000
# mean            2.361470         ...                  3.234127
# std             1.372995         ...                  1.323062
# min             1.000000         ...                  1.000000
# 25%             1.000000         ...                  2.000000
# 50%             2.000000         ...                  3.000000
# 75%             3.000000         ...                  4.000000
# max             5.000000         ...                  5.000000
#
#        Branded clothing  Entertainment spending  Spending on looks  \
# count       1008.000000             1007.000000        1007.000000
# mean           3.050595                3.201589           3.106256
# std            1.306321                1.188947           1.205368
# min            1.000000                1.000000           1.000000
# 25%            2.000000                2.000000           2.000000
# 50%            3.000000                3.000000           3.000000
# 75%            4.000000                4.000000           4.000000
# max            5.000000                5.000000           5.000000
#
#        Spending on gadgets  Spending on healthy eating          Age  \
# count          1010.000000                  1008.00000  1003.000000
# mean              2.870297                     3.55754    20.433699
# std               1.284970                     1.09375     2.828840
# min               1.000000                     1.00000    15.000000
# 25%               2.000000                     3.00000    19.000000
# 50%               3.000000                     4.00000    20.000000
# 75%               4.000000                     4.00000    22.000000
# max               5.000000                     5.00000    30.000000
#
#            Height      Weight  Number of siblings
# count  989.000000  988.000000          909.000000
# mean   173.626896   66.220648            1.294829
# std      9.380471   13.227183            1.046804
# min    148.000000   41.000000            0.000000
# 25%    167.000000   55.000000            1.000000
# 50%    173.000000   64.000000            1.000000
# 75%    180.000000   75.000000            2.000000
# max    203.000000  125.000000           10.000000
#
# [8 rows x 139 columns]

# %% [markdown]
# Some columns are not numerical. We want to apply collaborative filtering to only the columns that are numerical and relevant to matching.

# %%
df_cf = df.iloc[:,:140].select_dtypes(include=['float64', 'int64'])

# %%
df_cf.isnull().sum().sum()/(df.shape[0]*df.shape[1])
# Out:
# 0.0033964985902563767

# %% [markdown]
# Proportion of unanswered questions is small, so we should be able to use all the people for the recommender system.

# %%
#Centre each row
df_cf_centred = df_cf.sub(df_cf.mean(axis=1), axis=0)

# %%
df_cf_centred
# Out:
#          Music  Slow songs or fast songs     Dance      Folk   Country  \
# 0     2.177778                  0.177778 -0.822222 -1.822222 -0.822222
# 1     1.229630                  1.229630 -0.770370 -1.770370 -1.770370
# 2     1.807407                  1.807407 -1.192593 -1.192593 -0.192593
# 3     2.156716                  0.156716 -0.843284 -1.843284 -1.843284
# 4     2.022222                  0.022222  1.022222  0.022222 -0.977778
# 5     1.918519                 -0.081481 -1.081481 -0.081481 -1.081481
# 6     1.918519                  1.918519  1.918519 -0.081481 -2.081481
# 7     2.148148                  0.148148  0.148148 -0.851852 -1.851852
# 8     2.298507                  0.298507  0.298507 -1.701493 -1.701493
# 9     1.725926                 -0.274074 -1.274074  1.725926 -1.274074
# 10    2.096296                  0.096296  0.096296 -0.903704 -1.903704
# 11    2.096296                  0.096296 -1.903704 -1.903704 -1.903704
# 12    1.992593                 -0.007407 -2.007407 -1.007407 -2.007407
# 13    2.014815                  0.014815  2.014815  0.014815 -0.985185
# 14    1.800000                 -0.200000 -1.200000 -2.200000 -2.200000
# 15   -2.300752                 -0.300752 -1.300752 -1.300752 -0.300752
# 16    2.103704                  0.103704  0.103704 -1.896296 -1.896296
# 17    1.820896                 -0.179104 -0.179104 -0.179104 -0.179104
# 18    1.851852                 -0.148148  1.851852  0.851852 -0.148148
# 19    2.037037                  1.037037  0.037037  0.037037 -0.962963
# 20    1.814815                 -0.185185 -0.185185 -1.185185 -0.185185
# 6                       1.918519
# 7                      -0.851852
# 8                       1.298507
# 9                       0.725926
# 10                     -0.903704
# 11                     -0.903704
# 12                     -0.007407
# 13                      0.014815
# 14                      0.800000
# 15                      1.699248
# 16                      0.103704
# 17                      1.820896
# 18                      0.851852
# 19                      0.037037
# 20                      0.814815
# 21                     -0.866667
# 22                      1.135338
# 23                      0.748148
# 24                      1.392593
# 25                     -0.762963
# 26                     -0.474074
# 27                      0.074627
# 28                      1.896296
# 29                      0.429630
# ...                          ...
# 980                     1.007463
# 981                     1.088889
# 982                     1.333333
# 983                     1.000000
# 984                    -0.537313
# 985                     1.244444
# 986                    -0.977778
# 987                    -0.856061
# 988                     1.434109
# 989                     1.525926
# 990                    -1.548148
# 991                    -0.377778
# 992                     1.259259
# 993                     1.149254
# 994                     2.014925
# 995                     1.000000
# 996                     0.488889
# 997                    -1.111940
# 998                     1.837037
# 999                    -0.466165
# 1000                    1.896296
# 1001                    1.096296
# 1002                    0.611940
# 1003                    0.948148
# 1004                   -1.111111
# 1005                    0.785185
# 1006                    0.059701
# 1007                    2.459259
# 1008                   -0.192593
# 1009                    2.162963
#
# [1010 rows x 135 columns]

# %%
# fill nans with 0.0 (mean of centred rows)
df_cf_centred = df_cf_centred.fillna(0.)

# %%
from sklearn.neighbors import NearestNeighbors

#make an object for the NearestNeighbors Class.
model_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=10, n_jobs=-1)

# fit the dataset
model_knn.fit(df_cf_centred)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='cosine',
#          metric_params=None, n_jobs=-1, n_neighbors=10, p=2, radius=1.0)

# %%
distances, indices = model_knn.kneighbors(df_cf_centred)

# %%
indices
# Out:
# array([[   0,  894,  976, ...,  924,  717,  588],
#        [   1,  513,  892, ...,  934,  204,   47],
#        [   2,  741,   92, ...,  125,  753,  459],
#        ...,
#        [1007,  116,  957, ...,  258,  863,  666],
#        [1008,  427,   57, ...,  114,  402,  894],
#        [1009,   58,    6, ...,  764,  144,  574]], dtype=int64)

# %%
distances
# Out:
# array([[  0.00000000e+00,   4.74157564e-01,   5.04945905e-01, ...,
#           5.16244237e-01,   5.20171506e-01,   5.24008126e-01],
#        [  1.55431223e-15,   4.76317803e-01,   4.76697860e-01, ...,
#           4.98638929e-01,   5.04014807e-01,   5.13569928e-01],
#        [  0.00000000e+00,   5.11449515e-01,   5.39305960e-01, ...,
#           5.68302125e-01,   5.83837084e-01,   5.87625958e-01],
#        ...,
#        [  2.22044605e-16,   4.42861367e-01,   4.57120827e-01, ...,
#           5.21348933e-01,   5.30550328e-01,   5.31732649e-01],
#        [  2.22044605e-16,   5.12902756e-01,   5.16209757e-01, ...,
#           5.39212490e-01,   5.40631872e-01,   5.41146873e-01],
#        [  0.00000000e+00,   1.90602166e-01,   5.51147062e-01, ...,
#           5.90929640e-01,   5.98373006e-01,   6.03392217e-01]])

# %%
distances[:,1:].max()
# Out:
# 0.87642377922653503

# %%
np.where(distances == distances[:,1].min())
# Out:
# (array([449], dtype=int64), array([1], dtype=int64))

# %%
indices[449,:]
# Out:
# array([449, 453, 948, 593, 541, 441, 233, 380, 479, 660], dtype=int64)

# %%
df_cf_centred.iloc[[449,453],:]
# Out:
#         Music  Slow songs or fast songs     Dance      Folk   Country  \
# 449  1.947761                 -0.052239 -0.052239 -0.052239 -2.052239
# 453  1.948148                  0.948148 -1.051852 -1.051852 -2.051852
#
#      Classical music   Musical       Pop      Rock  Metal or Hardrock  \
# 449        -1.052239  1.947761 -0.052239  0.947761          -1.052239
# 453        -2.051852  1.948148 -0.051852  0.948148          -1.051852
#
#                 ...              Interests or hobbies  Parents' advice  \
# 449             ...                         -0.052239        -0.052239
# 453             ...                         -0.051852        -0.051852
#
#      Questionnaires or polls  Finances  Shopping centres  Branded clothing  \
# 449                -2.052239  1.947761         -2.052239         -0.052239
# 453                -2.051852  1.948148         -1.051852         -0.051852
#
#      Entertainment spending  Spending on looks  Spending on gadgets  \
# 449                0.947761          -1.052239            -1.052239
# 453                0.948148          -0.051852            -1.051852
#
#      Spending on healthy eating
# 449                   -0.052239
# 453                   -1.051852
#
# [2 rows x 135 columns]

# %%
# Aim: write a function where you enter your name and it lists the N best matches, their match score,
# plots the match scores, plots the interest trees.

def find_matches(index=None, name=None, n=10):
    if name is None and index is None:
        print('Enter an index or name.')
    elif name is None:
        name = df.iloc[index]['Name']
    elif index is None:
        index = list(df[df['Name'] == name].index)[0]
    
    match_indices = indices[index, 1:]
    match_names = list(df.iloc[match_indices]['Name'])
    match_distances = list(distances[index, 1:])
    
    return match_names, match_distances

# %%
name = 'Sally Abraham'

# %%
list(df[df['Name'] == name].index)[0]
# Out:
# 0

# %%
df.iloc[[1,2,3,40]]['Name']
# Out:
# 1     Rebecca Acheson
# 2      Carole Ackland
# 3     Hayley Alderton
# 40      Juliet Carter
# Name: Name, dtype: object

# %%
find_matches(name=name)
# Out:
# (['Jacqueline Newsam',
#   'Kelly Tolhurst',
#   'Gary Jones',
#   'Lynne Hardman',
#   'Shamshad Sadiq',
#   'Joanne Sharp',
#   'Elizabeth Purvis',
#   'Carmel Cole',
#   'Judith Sharp'],
#  [0.47415756411531584,
#   0.50494590511062099,
#   0.50853874172173597,
#   0.508862522841242,
#   0.51293349444436054,
#   0.51588999925673484,
#   0.51624423726322166,
#   0.52017150585596583,
#   0.52400812633815452])

# %%
find_matches(index=0)
# Out:
# (['Jacqueline Newsam',
#   'Kelly Tolhurst',
#   'Gary Jones',
#   'Lynne Hardman',
#   'Shamshad Sadiq',
#   'Joanne Sharp',
#   'Elizabeth Purvis',
#   'Carmel Cole',
#   'Judith Sharp'],
#  [0.47415756411531584,
#   0.50494590511062099,
#   0.50853874172173597,
#   0.508862522841242,
#   0.51293349444436054,
#   0.51588999925673484,
#   0.51624423726322166,
#   0.52017150585596583,
#   0.52400812633815452])

# %%
import matplotlib.pyplot as plt

# %%
x = range(9)
plt.bar(x,find_matches(index=0)[1])
plt.xticks(x, find_matches(index=0)[0], rotation='vertical')
plt.ylim([0.4, 0.6])
plt.show()
